# %%
import pandas as pd
import requests
import re
import json

# %%
data = json.load(open('data2.json'))

# %%
len(data['cards'])
# Out:
# 14

# %%
data['cards'][0]
# Out:
# {'cardFilter1Display': 'Les Républicains',
#  'cardFilter1Tri': 'f-republicain',
#  'cardFilter2Display': '23 ans',
#  'cardFilter2Tri': 'f-plus-20',
#  'cardFilter3Display': 'Homme',
#  'cardFilter3Tri': 'f-homme',
#  'cardFilter4Display': 'Oui',
#  'cardFilter4Tri': 'f-ena-oui',
#  'cardFilter5Display': 'Oui',
#  'cardFilter5Tri': 'f-industrie-oui',
#  'cardFilter6Display': 'Improbable',
#  'cardFilter6Tri': 'f-improbable',
#  'cardId': '1',
#  'cardImage': 'cope.jpg',
#  'cardInfo1': 'Né le 5 mai 1964 à Boulogne-Billancourt, ouest de Paris',
#  'cardInfo2': 'En politique depuis 1993',
#  'cardSection1Text': 'Diplômé de Sciences-Po Paris, énarque, avocat d’affaires. Maire de Meaux en 1995 élu sur une liste RPR dissidente, député, porte-parole du gouvernement, secrétaire d’État puis ministre délégué à l’Intérieur et au Budget de 2002 à 2007, plusieurs hauts postes à l’UMP entre 2012 à 2014 avant de devoir quitter sa présidence dans le sillage de l’affaire Bygmalion.',
# ...

# %%
df = pd.DataFrame(data['cards'])

# %%
df[['cardId',
    'cardTitre', 'cardSubtitle', 
    'cardImage', 
    'cardInfo1', # date naissance
    'cardInfo2', # années d'activité
    'cardFilter1Display', 'cardFilter1Tri',
    'cardFilter2Display', 'cardFilter2Tri',
    'cardFilter3Display', 'cardFilter3Tri',
    'cardFilter4Display', 'cardFilter4Tri',
    'cardFilter5Display', 'cardFilter5Tri',
    'cardFilter6Display', 'cardFilter6Tri',
    'cardSection1Title', 'cardSection1Text',
    'cardSection2Title', 'cardSection2Text', 
    'cardSection3Title', 'cardSection3Text', 
    'cardSection4Title', 'cardSection4Text',  
    'cardSection5Title', 'cardSection5Text', 
    'cardSection6Title', 'cardSection6Text', 
    'cardSection7Title', 'cardSection7Text'
    ]]
# Out:
#    cardId                   cardTitre  \
# 0       1          Jean-François Copé
# 1       2             Geoffroy Didier
# 2       3             François Fillon
# 3       4                Henri Guaino
# 4       5               Hassen Hammou
# 5       6                 Alain Juppé
# 6       7  Nathalie Kosciusko-Morizet
# 7       8           Frédéric Lefebvre
# 8       9              Bruno Le Maire
# 9      10              Hervé Mariton
# 10     11               Nadine Morano
# 11     12               Jacques Myard
# 12     13       Jean-Frédéric Poisson
# 13     14            Nicolas Sarkozy
#
#                                          cardSubtitle     cardImage  \
# 0     Chantre un peu dépassé de la droite décomplexée      cope.jpg
# 1   Le benjamin qui mise sur le changement de géné...  geoffroy.jpg
# 2                     Un austère provincial ambitieux    fillon.jpg
# 3   Du porte-plume de l’ombre au gaulliste social ...    guaino.jpg
# ...

# %%
df.to_csv('data.csv', index=False)

# %%
df
# Out:
#           cardFilter1Display cardFilter1Tri cardFilter2Display cardFilter2Tri  \
# 0           Les Républicains  f-republicain             23 ans      f-plus-20
# 1           Les Républicains  f-republicain            13 ans      f-moins-20
# 2           Les Républicains  f-republicain             35 ans      f-plus-20
# 3           Les Républicains  f-republicain             21 ans      f-plus-20
# 4           Les Républicains  f-republicain               1 an     f-moins-20
# 5           Les Républicains  f-republicain             40 ans      f-plus-20
# 6           Les Républicains  f-republicain             20 ans     f-moins-20
# 7           Les Républicains  f-republicain             25 ans      f-plus-20
# 8           Les Républicains  f-republicain             18 ans     f-moins-20
# 9           Les Républicains  f-republicain             30 ans      f-plus-20
# 10          Les Républicains  f-republicain             30 ans      f-plus-20
# ...
